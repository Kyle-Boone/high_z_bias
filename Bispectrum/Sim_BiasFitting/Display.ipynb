# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
os.listdir('/mnt/nvme1/kboone/Sims/Matter_Data')
# Out:
# ['d1.npy', 'd2.npy', 'd3.npy', 'K2.npy', 'd_2.npy']

# %%
L=2000
N=256

# %%
d = np.load('/mnt/nvme1/kboone/Sims/Matter_Data/d1.npy')
d2 = np.load('/mnt/nvme1/kboone/Sims/Matter_Data/d2.npy')
d3 = np.load('/mnt/nvme1/kboone/Sims/Matter_Data/d3.npy')
F2 = np.load('/mnt/nvme1/kboone/Sims/Matter_Data/d_2.npy')
K2 = np.load('/mnt/nvme1/kboone/Sims/Matter_Data/K2.npy')

# %%
np.std(d)
# Out:
# np.float32(0.18188679)

# %%
np.std(d2)
# Out:
# np.float32(0.049877927)

# %%
np.std(d3)
# Out:
# np.float32(0.019550543)

# %%
np.std(F2)
# Out:
# np.float32(0.050050832)

# %%
np.std(K2)
# Out:
# np.float32(0.017908294)

# %%
plt.figure(dpi=120)
plt.imshow(d[:, :, N//2], extent=(0, L, 0, L), origin='lower')
plt.colorbar()
plt.xlabel('x (Mpc/h)')
plt.ylabel('y (Mpc/h)')
plt.title(r'$\delta$ Slice at z = 8')
plt.show()

# %%
plt.figure(dpi=120)
plt.imshow(d2[:, :, N//2], extent=(0, L, 0, L), origin='lower')
plt.colorbar()
plt.xlabel('x (Mpc/h)')
plt.ylabel('y (Mpc/h)')
plt.title(r'$\delta^2$ Slice at z = 8')
plt.show()

# %%
plt.figure(dpi=120)
plt.imshow(d3[:, :, N//2], extent=(0, L, 0, L), origin='lower')
plt.colorbar()
plt.xlabel('x (Mpc/h)')
plt.ylabel('y (Mpc/h)')
plt.title(r'$\delta^3$ Slice at z = 8')
plt.show()

# %%
plt.figure(dpi=120)
plt.imshow(K2[:, :, N//2], extent=(0, L, 0, L), origin='lower')
plt.colorbar()
plt.xlabel('x (Mpc/h)')
plt.ylabel('y (Mpc/h)')
plt.title(r'$K^2$ Slice at z = 8')
plt.show()

# %%
plt.figure(dpi=120)
plt.imshow(F2[:, :, N//2], extent=(0, L, 0, L), origin='lower')
plt.colorbar()
plt.xlabel('x (Mpc/h)')
plt.ylabel('y (Mpc/h)')
plt.title(r'$\delta^{(2)}$ Slice at z = 8')
plt.show()
